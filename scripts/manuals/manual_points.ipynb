# %%
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %%
df = pd.read_csv('/Users/zmhoppinen/Documents/sarvalanche/local/observed/FAC_avy_export_2023-09-01_2024-08-31-2.csv')

# %%
df.plot(y = 'locationPoint.lat', x = 'locationPoint.lng', kind = 'scatter')
# Out:
# <Axes: xlabel='locationPoint.lng', ylabel='locationPoint.lat'>

# %%
ds =

# %%
for i,r in df.iterrows():
    print(r['locationPoint.lng'], r['locationPoint.lat'], r['date'])
    fig, ax = plt.subplots(1, 1)
    ax.scatter(r['locationPoint.lng'], r['locationPoint.lat'])
    plt.show()
# Out:
# -113.78 48.336 2024-03-15
# -113.934 48.156 2023-11-17
# -113.775 48.336 2023-11-15
# -113.815 48.632 2023-11-18
# -113.7793 48.332 2023-11-18
# -114.886 48.909 2024-01-07
# -113.826 48.637 2023-11-15
# -113.76 48.327 2024-03-15
# -114.889 48.918 2024-01-07
# -114.32 48.511 2023-12-02
# -114.342 48.502 2023-12-03
# -113.954 48.161 2023-12-02
# -113.4692 48.2301 2024-01-11
# -113.59 48.2647 2024-01-12
# -114.32 48.512 2023-12-02
# -113.5028 48.2562 2024-01-11
# -113.622 47.567 2024-04-02
# -114.008 48.246 2024-01-08
# -114.309 48.511 2023-12-05
# -114.029 48.236 2024-01-07
# -114.316 48.516 2024-01-06
# -113.934 48.155 2023-12-05
# -113.955 48.162 2023-12-05
# -114.321 48.517 2024-01-06
# ...
